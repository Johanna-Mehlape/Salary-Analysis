# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib
import seaborn as sns
sns.set

df = pd.read_csv('salary.csv')
# Out:
# Using matplotlib backend: TkAgg

# %%
df
# Out:
#           salary  exprior  yearsworked  yearsrank  market  degree  otherqual  \
# 0    53000.00000        0            0          0    1.17       1          0
# 1    58000.00000        1            0          0    1.24       1          0
# 2    45500.00000        0            0          0    1.21       1          0
# 3    35782.00000        0            2          1    0.99       1          0
# 4    34731.00000        0            2          2    0.91       1          0
# 5    56000.00000        1            0          0    1.19       1          0
# 6    61008.00000        0            2          2    1.33       1          0
# 7    39986.00000        0            2          0    0.99       1          0
# 8    36308.00000        0            2          1    0.85       1          0
# 9    55000.00000        0            0          0    1.23       1          0
# 10   55227.00000        0            3          3    1.23       1          0
# ...

# %%
df.head()
# Out:
#     salary  exprior  yearsworked  yearsrank  market  degree  otherqual  \
# 0  53000.0        0            0          0    1.17       1          0
# 1  58000.0        1            0          0    1.24       1          0
# 2  45500.0        0            0          0    1.21       1          0
# 3  35782.0        0            2          1    0.99       1          0
# 4  34731.0        0            2          2    0.91       1          0
#
#    position  male  Field  yearsabs
# 0         1     1      3         0
# 1         1     1      2         0
# 2         1     1      3         2
# 3         1     1      4         1
# 4         1     1      4         1

# %%
df.tail()
# Out:
#       salary  exprior  yearsworked  yearsrank  market  degree  otherqual  \
# 509  45906.0        6           17         11    0.92       1          0
# 510  60402.0        6           19          7    0.86       1          0
# 511  53187.0       19            7          6    0.78       1          0
# 512  56542.0        8           20         10    0.78       1          0
# 513  52662.0       13           25         11    0.78       1          0
#
#      position  male  Field  yearsabs
# 509         2     0      2        70
# 510         3     0      1        72
# 511         3     0      4        76
# 512         3     0      2        78
# 513         3     0      1       112

# %%
df.sample(5)
#a random sample of a few lines
# Out:
#       salary  exprior  yearsworked  yearsrank  market  degree  otherqual  \
# 438  36869.0        0            7          1    0.85       1          0
# 222  49768.0        0           26          7    0.90       1          0
# 368  64073.0        3           28         14    0.91       1          0
# 370  80103.0        2           29         22    0.93       1          0
# 487  34997.0        0           18         12    0.80       1          0
#
#      position  male  Field  yearsabs
# 438         2     0      1         4
# 222         3     1      2         1
# 368         3     1      2         3
# 370         3     1      2         0
# 487         2     0      3        49

# %%
df.describe()
#a summary of the data, and from here we are able to pick up that there is missing data from the count of responses for the 'salary' column
# Out:
#              salary     exprior  yearsworked   yearsrank      market  \
# count    513.000000  514.000000   514.000000  514.000000  514.000000
# mean   50863.220098    2.926070    12.852140    7.052529    0.948521
# std    12685.132358    4.791397     9.444695    6.414771    0.149380
# min    29000.000000    0.000000     0.000000    0.000000    0.710000
# 25%    40000.000000    0.000000     4.000000    2.000000    0.840000
# 50%    50096.000000    0.500000    12.000000    5.000000    0.920000
# 75%    60345.000000    4.000000    22.000000   12.000000    1.020000
# max    96156.000000   25.000000    41.000000   28.000000    1.330000
#
#            degree   otherqual    position        male       Field    yearsabs
# count  514.000000  514.000000  514.000000  514.000000  514.000000  514.000000
# mean     0.964981    0.044747    2.132296    0.750973    2.529183    6.982490
# std      0.184008    0.206950    0.820075    0.432871    1.127420   16.873156
# ...

# %%
print(df['salary'].isnull().sum())
#using the isnull(), we are then able to recognise that there is missing data, and with the .sum(), we are then able to see the summary of the missing values
# Out:
# 1

# %%
null_columns=df.columns[df.isnull().any()]
print(df[df['salary'].isnull()][null_columns])
#here I specifically looked for where the missing value was, and it is found that it is indeed in the 'salary' column and in row 208
# Out:
#      salary
# 208     NaN

# %%
df['salary'].mean()
# Out:
# 50863.22009783626

# %%
df['salary'].sem()
# Out:
# 560.0622753925232

# %%
df['yearsworked'].std()
# Out:
# 9.444695144169813

# %%
df['salary'].median()
# Out:
# 50096.0

# %%
men = df['male'].value_counts()
print(men)
#the number of ones represent the inputs from men and the number of zeros represent the inputs from women
# Out:
# 1    386
# 0    128
# Name: male, dtype: int64

# %%
execs = df['position'].value_counts()
execs.columns = ['position', 'male']
print(execs)
#the rankings were as follows: 1= Junior Employee, 2 = Manager, 3 = Executives, and we could see that there are 211 executives inclusive of both genders. so now I need to work out how many wpmen are in that 211.
# Out:
# 3    211
# 2    160
# 1    143
# Name: position, dtype: int64

# %%
women_execs = df.groupby(['position', 'male']).size()
print(women_execs)
#now we can see the amount of women in each category compared to men
# Out:
# position  male
# 1         0        60
#           1        83
# 2         0        49
#           1       111
# 3         0        19
#           1       192
# dtype: int64

# %% [markdown]
# # Predicting Salaries Differences
#
# ## Questions and answers
#
# Question 1
#
#     a) How many responders are there? Are there any missing values in any of the variables?
# Ans: There are 514 responders and yes there are missing values( for salaries there are 513 responses.
#
#     b What is the lowest salary and highest salary in the group?
# Ans: Lowest salary is 29000 dollars, Highest salary is 95156 dollars
#
#     c) What is the mean salary for the sample? Include the standard error of the mean.
# Ans: Mean salary = 50863.22, Standard Error of mean = 560.06
#
#     d) What is the standard deviation for the years worked?
# Ans: Standard Deviation for the years worked = 9.44
#
#     e) What is the median salary for the sample?
# Ans: Median salary = 50096
#
#     f) What is the interquartile range for salary in the sample?
# Ans: IQR['salary'] = Q3 - Q1 60345.000000 - 40000.000000 = 20345
#
#     g) How many men are there in the sample? How many women are there in the sample? Present this information in a table.
#
#             Men     |   Women
#         ============|===========
#             386     |   128
#
#     h) How many women are executives compared to men?
# Ans: 19 women are executives compared to men
#
#     i) Create a histogram for the variable Salary.
# Ans: see graph below
#
#     j) Examine the histogram and describe the distribution for Salary.
# Ans: The distribution for Salary is skewed right,this shows that most people earn within the low/medium range  of salaries, with a few exceptions, being executives and some managers, that are distributed ona large range of higher salary.
#
#     k) Create a bar graph to show the different average salaries of men and women. (Bonus: Add error bars to the bars showing the 95% confidence interval). What does the graph tell you about the difference between men and women’s salaries?
# Ans: (see graph below to support this answer)
# The average salary for women is less than that of the men.
#
#     l) Create a scatterplot showing the relationship between Years Worked and Salary (don’t forget to insert a trend line). What is the relationship between Years Worked and Salary?
# Ans:

# %%
#answer to i) 
#Salary histogram

df1 = plt.hist(df['salary'])
df1 = plt.xlabel('Salary')
df1 = plt.title('Distribution of salaries')
plt.show()
# Out:
# /home/johanna/.local/lib/python3.6/site-packages/numpy/lib/histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /home/johanna/.local/lib/python3.6/site-packages/numpy/lib/histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
avg_salary = df.groupby('male').mean()
avg_salary['salary'].plot(kind='bar')
plt.xlabel('Gender')
plt.show()
